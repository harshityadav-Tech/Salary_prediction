# %%
import numpy as np,pandas as pd,seaborn as sns, matplotlib.pyplot as plt

# %%
df=pd.read_csv("Salary_Data.csv")
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
plt.scatter(df['YearsExperience'],df['Salary'])

# %%
print("The data is clean")
X=df[['YearsExperience']]
y=df[['Salary']]
# Out:
# The data is clean

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=45)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model
# Out:
# LinearRegression()

# %%
#Model Fitting for Training
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#Prediction
Pred=model.predict(X_test)

# %%
from sklearn.metrics import r2_score
print("R2_score",r2_score(y_test,Pred))
# Out:
# R2_score 0.8824679635169839

# %%
exp=float(input("Enter Experience:"))
exp=np.array([[exp]])
pred_sal=model.predict(exp)
print(f"Predicted Salary: {pred_sal[0][0]:.2f}")
# Out:
# Enter Experience: 5
# Predicted Salary: 72095.12
# C:\Users\harsh\Downloads\Anaconda File\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import joblib as jb
jb.dump(model,"Salary_model.pkl")
print("Model Saved Successfully")
# Out:
# Model Saved Successfully
